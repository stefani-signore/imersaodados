# %% [markdown]
# <a href="https://colab.research.google.com/github/stefani-signore/imersaodados/blob/main/Passo_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###Passo 2: Verificando os 5 compostos mais usados e suas respectivas reações.

# %%
import pandas as pd

url_dados = 'https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_experimentos.zip?raw=true'

dados = pd.read_csv(url_dados, compression = 'zip')
dados
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0      id_000644bb2     com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1      id_000779bfc     com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2      id_000a6266a     com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3      id_0015fd391     com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4      id_001626bd3     com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23809  id_fffb1ceed     com_droga     24   D2  ...  0.0631  0.9171  0.5258  0.4680
# 23810  id_fffb70c0c     com_droga     24   D2  ... -0.2084 -0.1224 -0.2715  0.3689
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# 23812  id_fffcb9e7c     com_droga     24   D1  ...  0.1732  0.7015 -0.6290  0.0740
# ...

# %%
import matplotlib.pyplot as plt
import matplotlib.colors as mcolors

# %% [markdown]
# **Renomeando coluna**

# %%
mapa = {'droga': 'composto'}
dados.rename(columns=mapa, inplace=True)
dados.head()
# Out:
#              id tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 0  id_000644bb2  com_droga     24   D1  ... -0.3981  0.2139  0.3801  0.4176
# 1  id_000779bfc  com_droga     72   D1  ...  0.1522  0.1241  0.6077  0.7371
# 2  id_000a6266a  com_droga     48   D1  ... -0.6417 -0.2187 -1.4080  0.6931
# 3  id_0015fd391  com_droga     48   D1  ... -1.6210 -0.8784 -0.3876 -0.8154
# 4  id_001626bd3  com_droga     72   D2  ...  0.1094  0.2885 -0.3786  0.7125
#
# [5 rows x 877 columns]

# %% [markdown]
# *Verificando os 5 compostos mais usados*

# %%
dados['composto'].value_counts()
# Out:
# cacb2b860    1866
# 87d714366     718
# 9f80f3f77     246
# 8b87a7a83     203
# 5628cb3ee     202
#              ...
# b046f598b       1
# 82dcdb180       1
# b01cf573a       1
# 29d24570f       1
# 27fa72002       1
# Name: composto, Length: 3289, dtype: int64

# %%
cod_compostos = dados['composto'].value_counts().index[0:5]
cod_compostos
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %%
dados.query('composto in @cod_compostos')
# Out:
#                  id    tratamento  tempo dose  ...    c-96    c-97    c-98    c-99
# 7      id_0020d0484     com_droga     48   D1  ...  0.6633  0.4562 -0.9622  0.0260
# 16     id_002fb9c19     com_droga     48   D1  ... -9.9840 -9.9840 -9.9840 -6.7840
# 25     id_0054388ec  com_controle     48   D1  ...  0.8837  0.5534  0.8976  1.0050
# 38     id_0079af0fb  com_controle     24   D1  ...  0.2187  0.0737  0.6498 -1.4820
# 40     id_007bfbb91  com_controle     24   D2  ... -0.5751  0.3362  0.8543  0.9180
# ...             ...           ...    ...  ...  ...     ...     ...     ...     ...
# 23793  id_ffd26f361  com_controle     48   D2  ...  0.8813  0.7757 -0.5272  0.7082
# 23802  id_fff3976bd     com_droga     24   D1  ... -8.4480 -4.4550 -5.7930 -3.7000
# 23805  id_fff6df1c5     com_droga     48   D2  ...  0.1516  0.4503 -0.6312 -0.8302
# 23811  id_fffc1c3f4  com_controle     48   D2  ...  0.2256  0.7592  0.6656  0.3808
# ...

# %% [markdown]
# *Ordenando valores do gráfico de barras.*

# %%
import seaborn as sns
sns.set()
plt.figure(figsize=(8,6))
sort_compostos = dados.query('composto in @cod_compostos')
ax = sns.countplot(
    x = 'composto', 
    data = sort_compostos, 
    order = sort_compostos['composto'].value_counts().index
)
ax.set_title('Top 5 Compostos')
plt.show()

# %% [markdown]
# ## Explorando a segunda base de dados.

# %%
dados_resultados = pd.read_csv('https://github.com/alura-cursos/imersaodados3/blob/main/dados/dados_resultados.csv?raw=true')
dados_resultados.head()
# Out:
#              id  ...  wnt_inhibitor
# 0  id_000644bb2  ...              0
# 1  id_000779bfc  ...              0
# 2  id_000a6266a  ...              0
# 3  id_0015fd391  ...              0
# 4  id_001626bd3  ...              0
#
# [5 rows x 207 columns]

# %% [markdown]
# Quantas vezes um mecanismo de ação foi ativado.

# %%
dados_resultados['n_moa'] = dados_resultados.drop('id', axis=1).sum(axis=1)
dados_resultados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  wnt_inhibitor  n_moa
# 0      id_000644bb2                            0  ...              0      1
# 1      id_000779bfc                            0  ...              0      0
# 2      id_000a6266a                            0  ...              0      3
# 3      id_0015fd391                            0  ...              0      0
# 4      id_001626bd3                            0  ...              0      1
# ...             ...                          ...  ...            ...    ...
# 23809  id_fffb1ceed                            0  ...              0      1
# 23810  id_fffb70c0c                            0  ...              0      1
# 23811  id_fffc1c3f4                            0  ...              0      0
# 23812  id_fffcb9e7c                            0  ...              0      1
# 23813  id_ffffdd77b                            0  ...              0      0
#
# [23814 rows x 208 columns]

# %%
dados_resultados['ativo_moa'] = (dados_resultados['n_moa'] !=0)
dados_resultados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  n_moa  ativo_moa
# 0      id_000644bb2                            0  ...      1       True
# 1      id_000779bfc                            0  ...      0      False
# 2      id_000a6266a                            0  ...      3       True
# 3      id_0015fd391                            0  ...      0      False
# 4      id_001626bd3                            0  ...      1       True
# ...             ...                          ...  ...    ...        ...
# 23809  id_fffb1ceed                            0  ...      1       True
# 23810  id_fffb70c0c                            0  ...      1       True
# 23811  id_fffc1c3f4                            0  ...      0      False
# 23812  id_fffcb9e7c                            0  ...      1       True
# 23813  id_ffffdd77b                            0  ...      0      False
#
# [23814 rows x 209 columns]

# %% [markdown]
# **Fazendo merge com as duas bases de dados**

# %%
dados_combinados = pd.merge(dados, dados_resultados[['id', 'n_moa', 'ativo_moa']], on='id')
dados_combinados.head()
# Out:
#              id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0  id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 1  id_000779bfc  com_droga     72   D1  ...  0.6077  0.7371      0      False
# 2  id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 3  id_0015fd391  com_droga     48   D1  ... -0.3876 -0.8154      0      False
# 4  id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
#
# [5 rows x 879 columns]

# %% [markdown]
# **Visualizando os 5 compostos mais usados em formato de lista.**

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
composto_principal
# Out:
# Index(['cacb2b860', '87d714366', '9f80f3f77', '8b87a7a83', '5628cb3ee'], dtype='object')

# %% [markdown]
# **Demonstração com base no *g-0* dos compostos mais usados e suas respectivas reações a alguma propriedade.**

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(10,6))
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'), y='g-0', x='composto', hue='ativo_moa')

# %%
composto_principal = dados_combinados['composto'].value_counts().index[:5]
plt.figure(figsize=(12,8)) 
sns.set_style("whitegrid")
sns.boxplot(data = dados_combinados.query('composto in @composto_principal'),
            y='g-0',
            x='composto',
            hue='ativo_moa',
            dodge=False, # Align the seaborn boxplot to its x ticks centerly
            width=.4 #Control the width of boxplots
)
sns.despine(left=True)

# %%
mecanismos_ativados = pd.merge(dados_resultados, dados[['id', 'composto']], on='id')
mecanismos_ativados
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  ativo_moa   composto
# 0      id_000644bb2                            0  ...       True  b68db1d53
# 1      id_000779bfc                            0  ...      False  df89a8e5a
# 2      id_000a6266a                            0  ...       True  18bb41b2c
# 3      id_0015fd391                            0  ...      False  8c7f86626
# 4      id_001626bd3                            0  ...       True  7cbed3131
# ...             ...                          ...  ...        ...        ...
# 23809  id_fffb1ceed                            0  ...       True  df1d0a5a1
# 23810  id_fffb70c0c                            0  ...       True  ecf3b6b74
# 23811  id_fffc1c3f4                            0  ...      False  cacb2b860
# 23812  id_fffcb9e7c                            0  ...       True  8b87a7a83
# 23813  id_ffffdd77b                            0  ...      False  972f41291
#
# [23814 rows x 210 columns]

# %%
mecanismos_segundocomp = mecanismos_ativados.loc[(mecanismos_ativados['composto'] =='87d714366')]
#mecanismos_segundocomp = pd.set_option('max_columns', None)
mecanismos_segundocomp
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  ativo_moa   composto
# 16     id_002fb9c19                            0  ...       True  87d714366
# 76     id_00cf039a7                            0  ...       True  87d714366
# 119    id_01534c4ee                            0  ...       True  87d714366
# 209    id_0236e3425                            0  ...       True  87d714366
# 218    id_024a52260                            0  ...       True  87d714366
# ...             ...                          ...  ...        ...        ...
# 23680  id_fe8abffe0                            0  ...       True  87d714366
# 23727  id_ff1d43f96                            0  ...       True  87d714366
# 23776  id_ff9d0a022                            0  ...       True  87d714366
# 23791  id_ffd1fd119                            0  ...       True  87d714366
# 23802  id_fff3976bd                            0  ...       True  87d714366
#
# [718 rows x 210 columns]

# %%
mecanismos_segundocomp2 = mecanismos_segundocomp[['nfkb_inhibitor', 'proteasome_inhibitor', 'composto']]
mecanismos_segundocomp2
# Out:
#        nfkb_inhibitor  proteasome_inhibitor   composto
# 16                  1                     1  87d714366
# 76                  1                     1  87d714366
# 119                 1                     1  87d714366
# 209                 1                     1  87d714366
# 218                 1                     1  87d714366
# ...               ...                   ...        ...
# 23680               1                     1  87d714366
# 23727               1                     1  87d714366
# 23776               1                     1  87d714366
# 23791               1                     1  87d714366
# 23802               1                     1  87d714366
#
# [718 rows x 3 columns]

# %%
#from google.colab import files
#mecanismos_segundocomp.to_csv('segundocomp.csv')
#files.download('segundocomp.csv')

# %%
mecanismos_segundocomp_t = mecanismos_segundocomp.transpose()
mecanismos_segundocomp_t
# Out:
#                                        16     ...         23802
# id                              id_002fb9c19  ...  id_fff3976bd
# 5-alpha_reductase_inhibitor                0  ...             0
# 11-beta-hsd1_inhibitor                     0  ...             0
# acat_inhibitor                             0  ...             0
# acetylcholine_receptor_agonist             0  ...             0
# ...                                      ...  ...           ...
# vitamin_d_receptor_agonist                 0  ...             0
# wnt_inhibitor                              0  ...             0
# n_moa                                      2  ...             2
# ativo_moa                               True  ...          True
# composto                           87d714366  ...     87d714366
#
# [210 rows x 718 columns]

# %%
#mecanismos_segundocomp = pd.set_option('max_columns', None)
#mecanismos_segundocomp

# %%
# %load_ext google.colab.data_table

# %%
mecanismos_segundocomp.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 718 entries, 16 to 23802
# Columns: 210 entries, id to composto
# dtypes: bool(1), int64(207), object(2)
# memory usage: 1.2+ MB

# %%
mecanismos_terceirocomp = mecanismos_ativados.loc[(mecanismos_ativados['composto'] =='9f80f3f77')]
mecanismos_terceirocomp
# Out:
#                  id  5-alpha_reductase_inhibitor  ...  ativo_moa   composto
# 75     id_00ceee87f                            0  ...       True  9f80f3f77
# 251    id_02945c933                            0  ...       True  9f80f3f77
# 337    id_03a148573                            0  ...       True  9f80f3f77
# 355    id_03d57c47a                            0  ...       True  9f80f3f77
# 404    id_04495c8c8                            0  ...       True  9f80f3f77
# ...             ...                          ...  ...        ...        ...
# 23400  id_fb9af8d4b                            0  ...       True  9f80f3f77
# 23604  id_fd9b2b44a                            0  ...       True  9f80f3f77
# 23675  id_fe7394162                            0  ...       True  9f80f3f77
# 23762  id_ff78a40f0                            0  ...       True  9f80f3f77
# 23774  id_ff96bcd4d                            0  ...       True  9f80f3f77
#
# [246 rows x 210 columns]

# %%
ativados_terceirocomp = mecanismos_terceirocomp[['nfkb_inhibitor', 'proteasome_inhibitor', 'hmgcr_inhibitor', 'composto']]
ativados_terceirocomp
# Out:
#        nfkb_inhibitor  proteasome_inhibitor  hmgcr_inhibitor   composto
# 75                  0                     0                1  9f80f3f77
# 251                 0                     0                1  9f80f3f77
# 337                 0                     0                1  9f80f3f77
# 355                 0                     0                1  9f80f3f77
# 404                 0                     0                1  9f80f3f77
# ...               ...                   ...              ...        ...
# 23400               0                     0                1  9f80f3f77
# 23604               0                     0                1  9f80f3f77
# 23675               0                     0                1  9f80f3f77
# 23762               0                     0                1  9f80f3f77
# 23774               0                     0                1  9f80f3f77
#
# [246 rows x 4 columns]

# %% [markdown]
# *Queremos verificar quantas substâncias/genes tiveram alguma propriedade ativada durante o tratamento com controle (sem droga).
# O ideal aqui é que nenhuma propriedade conste como ativa, por isso queremos um **True = 0**, se não é usada nenhuma droga durante o tratamento com controle, não há motivos para que alguma propriedade seja ativada.*

# %%
dados_combinados.query('tratamento == "com_controle"')['ativo_moa'].value_counts()
# Out:
# False    1866
# Name: ativo_moa, dtype: int64

# %% [markdown]
# *Abaixo, vamos verificar quantas substâncias/genes tiveram alguma propriedade ativada ou não durante o tratamento com droga.*

# %%
dados_combinados.query('tratamento == "com_droga"')['ativo_moa'].value_counts()
# Out:
# True     14447
# False     7501
# Name: ativo_moa, dtype: int64

# %% [markdown]
# ###Selecionando apenas as linhas com algum n_moa ativo.

# %%
dados_combinados.loc[dados_combinados['n_moa'] !=0]
# Out:
#                  id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 2      id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 4      id_001626bd3  com_droga     72   D2  ... -0.3786  0.7125      1       True
# 5      id_001762a82  com_droga     24   D1  ...  0.7848  1.3990      1       True
# 7      id_0020d0484  com_droga     48   D1  ... -0.9622  0.0260      1       True
# ...             ...        ...    ...  ...  ...     ...     ...    ...        ...
# 23807  id_fff7e6992  com_droga     48   D1  ...  0.4494  0.1218      1       True
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.4259  0.2434      1       True
# 23809  id_fffb1ceed  com_droga     24   D2  ...  0.5258  0.4680      1       True
# 23810  id_fffb70c0c  com_droga     24   D2  ... -0.2715  0.3689      1       True
# ...

# %%
dados_combinados.loc[(dados_combinados['n_moa'] !=0) & (dados_combinados['dose'] =='D1')]
# Out:
#                  id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 2      id_000a6266a  com_droga     48   D1  ... -1.4080  0.6931      3       True
# 5      id_001762a82  com_droga     24   D1  ...  0.7848  1.3990      1       True
# 7      id_0020d0484  com_droga     48   D1  ... -0.9622  0.0260      1       True
# 12     id_0025c5949  com_droga     48   D1  ...  0.3453  0.3083      1       True
# ...             ...        ...    ...  ...  ...     ...     ...    ...        ...
# 23802  id_fff3976bd  com_droga     24   D1  ... -5.7930 -3.7000      2       True
# 23803  id_fff485da4  com_droga     48   D1  ... -0.4622  0.8154      1       True
# 23807  id_fff7e6992  com_droga     48   D1  ...  0.4494  0.1218      1       True
# 23808  id_fff8c2444  com_droga     72   D1  ... -0.4259  0.2434      1       True
# ...

# %%
dados_combinados.loc[(dados_combinados['n_moa'] !=0) & (dados_combinados['dose'] =='D1') & (dados_combinados['tempo']==24)]
# Out:
#                  id tratamento  tempo dose  ...    c-98    c-99  n_moa  ativo_moa
# 0      id_000644bb2  com_droga     24   D1  ...  0.3801  0.4176      1       True
# 5      id_001762a82  com_droga     24   D1  ...  0.7848  1.3990      1       True
# 48     id_008b48693  com_droga     24   D1  ... -0.4635 -0.1365      1       True
# 56     id_009379beb  com_droga     24   D1  ... -1.3720  0.4935      1       True
# 57     id_0093bf6b8  com_droga     24   D1  ... -0.5149 -0.1872      3       True
# ...             ...        ...    ...  ...  ...     ...     ...    ...        ...
# 23786  id_ffc9721f4  com_droga     24   D1  ... -0.5015  0.0025      1       True
# 23787  id_ffcb7e365  com_droga     24   D1  ...  0.1258  0.4556      1       True
# 23796  id_ffe18c87f  com_droga     24   D1  ... -0.2315 -0.8074      1       True
# 23802  id_fff3976bd  com_droga     24   D1  ... -5.7930 -3.7000      2       True
# ...

# %%
dados_combinados[['tratamento','tempo','dose', 'n_moa', 'ativo_moa']]
# Out:
#          tratamento  tempo dose  n_moa  ativo_moa
# 0         com_droga     24   D1      1       True
# 1         com_droga     72   D1      0      False
# 2         com_droga     48   D1      3       True
# 3         com_droga     48   D1      0      False
# 4         com_droga     72   D2      1       True
# ...             ...    ...  ...    ...        ...
# 23809     com_droga     24   D2      1       True
# 23810     com_droga     24   D2      1       True
# 23811  com_controle     48   D2      0      False
# 23812     com_droga     24   D1      1       True
# 23813     com_droga     72   D1      0      False
#
# [23814 rows x 5 columns]

# %% [markdown]
# Um dos compostos mais utilizados fazia parte do tratamento com controle.

# %%
df_composto = dados_combinados[['tratamento','tempo','dose','composto','n_moa']]
df_composto = df_composto.loc[(df_composto['tratamento'] =="com_controle") & (df_composto['composto'] =='cacb2b860') & (df_composto['n_moa'] ==0)] 
df_composto
# Out:
#          tratamento  tempo dose   composto  n_moa
# 25     com_controle     48   D1  cacb2b860      0
# 38     com_controle     24   D1  cacb2b860      0
# 40     com_controle     24   D2  cacb2b860      0
# 47     com_controle     48   D2  cacb2b860      0
# 63     com_controle     24   D2  cacb2b860      0
# ...             ...    ...  ...        ...    ...
# 23729  com_controle     24   D1  cacb2b860      0
# 23747  com_controle     72   D1  cacb2b860      0
# 23768  com_controle     72   D2  cacb2b860      0
# 23793  com_controle     48   D2  cacb2b860      0
# 23811  com_controle     48   D2  cacb2b860      0
#
# [1866 rows x 5 columns]

# %% [markdown]
# Segundo composto mais usado faz parte do tratamento com droga.

# %%
df_segundocomposto = dados_combinados[['tratamento','tempo','dose','composto','n_moa']]
df_segundocomposto = df_segundocomposto.loc[(df_segundocomposto['tratamento'] =="com_controle") & (df_segundocomposto['composto'] =='87d714366') & (df_segundocomposto['n_moa'] ==0)] 
df_segundocomposto
# Out:
# Empty DataFrame
# Columns: [tratamento, tempo, dose, composto, n_moa]
# Index: []

# %%
df_segundocomposto = dados_combinados[['tratamento','tempo','dose','composto','n_moa']]
df_segundocomposto = df_segundocomposto.loc[(df_segundocomposto['tratamento'] =="com_droga") & (df_segundocomposto['composto'] =='87d714366') & (df_segundocomposto['n_moa'] !=0)] 
df_segundocomposto
# Out:
#       tratamento  tempo dose   composto  n_moa
# 16     com_droga     48   D1  87d714366      2
# 76     com_droga     48   D2  87d714366      2
# 119    com_droga     72   D2  87d714366      2
# 209    com_droga     72   D1  87d714366      2
# 218    com_droga     24   D2  87d714366      2
# ...          ...    ...  ...        ...    ...
# 23680  com_droga     72   D1  87d714366      2
# 23727  com_droga     24   D2  87d714366      2
# 23776  com_droga     24   D2  87d714366      2
# 23791  com_droga     72   D2  87d714366      2
# 23802  com_droga     24   D1  87d714366      2
#
# [718 rows x 5 columns]

# %%
df_segundocomposto.head(20)
# Out:
#     tratamento  tempo dose   composto  n_moa
# 16   com_droga     48   D1  87d714366      2
# 76   com_droga     48   D2  87d714366      2
# 119  com_droga     72   D2  87d714366      2
# 209  com_droga     72   D1  87d714366      2
# 218  com_droga     24   D2  87d714366      2
# 246  com_droga     48   D1  87d714366      2
# 249  com_droga     48   D1  87d714366      2
# 289  com_droga     72   D1  87d714366      2
# 336  com_droga     48   D1  87d714366      2
# 348  com_droga     72   D1  87d714366      2
# 359  com_droga     24   D1  87d714366      2
# 397  com_droga     72   D2  87d714366      2
# 414  com_droga     48   D2  87d714366      2
# 423  com_droga     72   D1  87d714366      2
# 428  com_droga     24   D2  87d714366      2
# 469  com_droga     72   D2  87d714366      2
# 502  com_droga     72   D1  87d714366      2
# 528  com_droga     72   D1  87d714366      2
# 560  com_droga     48   D1  87d714366      2
# 581  com_droga     48   D2  87d714366      2

# %%
df_segundocomposto['tempo'].value_counts()
# Out:
# 48    247
# 72    236
# 24    235
# Name: tempo, dtype: int64

# %% [markdown]
# Terceiro composto mais usado faz parte do tratamento com droga.

# %%
df_terceirocomposto = dados_combinados[['tratamento','tempo','dose','composto','n_moa']]
df_terceirocomposto = df_terceirocomposto.loc[(df_terceirocomposto['tratamento'] =="com_droga") & (df_terceirocomposto['composto'] =='9f80f3f77') & (df_terceirocomposto['n_moa'] !=0)] 
df_terceirocomposto
# Out:
#       tratamento  tempo dose   composto  n_moa
# 75     com_droga     24   D2  9f80f3f77      1
# 251    com_droga     48   D1  9f80f3f77      1
# 337    com_droga     48   D2  9f80f3f77      1
# 355    com_droga     24   D1  9f80f3f77      1
# 404    com_droga     24   D1  9f80f3f77      1
# ...          ...    ...  ...        ...    ...
# 23400  com_droga     24   D2  9f80f3f77      1
# 23604  com_droga     72   D2  9f80f3f77      1
# 23675  com_droga     24   D1  9f80f3f77      1
# 23762  com_droga     24   D1  9f80f3f77      1
# 23774  com_droga     48   D1  9f80f3f77      1
#
# [246 rows x 5 columns]

# %%
df_terceirocomposto['tempo'].value_counts()
# Out:
# 48    86
# 72    81
# 24    79
# Name: tempo, dtype: int64
